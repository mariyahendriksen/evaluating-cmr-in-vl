# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload
# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

import sys
from munch import Munch

PROJECT_PATH = '/Users/mhendriksen/Desktop/repositories/evaluating-cmr-in-mm/'
CONFIG_PATH = '/Users/mhendriksen/Desktop/repositories/evaluating-cmr-in-mm/config/development_local.yaml'

sys.path.append(PROJECT_PATH)

with open(CONFIG_PATH, 'rb') as f:
    config = Munch.fromYAML(f)

# %%
from src.utils.dataset_preprocessing import load_json_annotations

json_file = load_json_annotations(config=config, dataset_name='f30k')

# %%
from PIL import Image

path = '/Users/mhendriksen/Desktop/repositories/datasets/f30k/flickr30k-images/1000523639.jpg'


for el in json_file['images'][5]['sentences']:
    print(el['raw'])

Image.open(path)
# Out:
# Two people in the photo are playing the guitar and the other is poking at him.
# A man in green holds a guitar while the other man observes his shirt.
# A man is fixing the guitar players costume.
# A guy stitching up another man's coat.
# The two boys playing guitar
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>

# %%
import os
import json

extended_f30k_root = '/Users/mhendriksen/Desktop/repositories/datasets/MSCOCO-Flikcr30K_FG-master/Annotations/'

f30k_ann_path = os.path.join(extended_f30k_root, 'Flickr30K_FG_ann.json')

with open(f30k_ann_path, 'rb') as f:
    extended_f30k = json.load(f)

# %%
extended_f30k.keys()
# Out:
# dict_keys(['1007129816', '1009434119', '101362133', '102617084', '10287332', '1039637574', '1043819504', '1043910339', '1044798682', '1071201387', '107969134', '1080230428', '1082250005', '1089059626', '109260218', '109656696', '1104087374', '110671448', '111497985', '1131056918', '1144865997', '1153704539', '1159381599', '1167908324', '1181708011', '118865844', '121178216', '12252043', '1229536824', '123314995', '1250181412', '1253095131', '1255504166', '1258913059', '1281282435', '1287704027', '1295476404', '129860826', '130063845', '1313869424', '1313961775', '133010954', '1332208215', '1333888922', '1341077576', '1351500610', '136581487', '136693281', '1368082221', '139245992', '1395410911', '1396064003', '1397344877', '1404832008', '1408554531', '14133592', '1414911626', '1417882092', '1433088025', '14559446', '1459582913', '1463072715', '146906547', '1489286545', '150411291', '151970521', '1526325728', '155210731', '157910841', '1579198375', '1579206585', '157955034', '16079259
# ...

# %%
# for my_dict in json_file['images'][5]:
#     for el in my_dict['sentences']:
#         print(el['raw'])

my_dict = json_file['images'][25]

print('File: ', my_dict['filename'])

for el in my_dict['sentences']:
    print(el['raw'])
# Out:
# File:  1007129816.jpg
# The man with pierced ears is wearing glasses and an orange hat.
# A man with glasses is wearing a beer can crocheted hat.
# A man with gauges and glasses is wearing a Blitz hat.
# A man in an orange hat starring at something.
# A man wears an orange hat and glasses.

# %%
for idx, el in enumerate(json_file['images']):
    if el['split'] == 'test':
        print(idx)
        break
# Out:
# 25

# %%
# Out:
#   Cell In[66], line 1
#     The man with pierced ears is wearing glasses and an orange hat.
#         ^
# SyntaxError: invalid syntax

# %%
extended_f30k['1007129816']
# Out:
# ['the man with pierced ears is wearing glasses and an orange hat on his head',
#  'a man with glasses is wearing a beer can crocheted hat',
#  'a man with pierced ears and glasses is wearing an orange hat on his head',
#  'a man in an orange hat starring at something',
#  'a man wears an orange hat and glasses']
